# %% [markdown]
# # Load required packages

# %%
import pandas as pd
import numpy as np

# validation strategy 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle

# models
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# error measure/metrics
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report

# %% [markdown]
# # Load Datasets - cleaned and one-hot encoded

# %%
# load epilepsy dataset 
epilepsy = pd.read_csv("./Datasets/OneHotEpilepsyCleaned.csv", sep= ',', decimal= '.', on_bad_lines = 'error', skip_blank_lines=False)

# load dementia dataset 
dementia = pd.read_csv("./Datasets/OneHotDementiaCleaned.csv", sep= ',', decimal= '.', on_bad_lines = 'error', skip_blank_lines=False)

# %% [markdown]
# # Check data loaded is correct

# %%
pd.set_option('display.max_columns', None)

# %%
epilepsy.head()
# Out:
#    Age  Weight  Height  Seizure Frequency  Seizure Duration Epilepsy Type  \
# 0   15    48.3   168.2                  1                60   Generalised
# 1   36    44.8   156.2                  3                30   Generalised
# 2   32    70.4   180.4                  0                60         Focal
# 3   29    54.5   161.7                  1                60   Generalised
# 4   18    62.1   168.0                  1                30   Generalised
#
#    Gender_Female  Gender_Male  Gender_Other  \
# 0          False         True         False
# 1           True        False         False
# 2           True        False         False
# 3          False         True         False
# 4          False         True         False
#
#    Medication Status_Not on Medication  Medication Status_On Medication  \
# 0                                False                             True
# 1                                False                             True
# 2                                 True                            False
# 3                                False                             True
# 4                                False                             True
#
#    Alcohol or Drug Use_No  Alcohol or Drug Use_Yes  \
# 0                   False                     True
# 1                    True                    False
# 2                    True                    False
# 3                    True                    False
# 4                    True                    False
#
#    EEG Abnormality Detected_No  EEG Abnormality Detected_Yes  \
# 0                        False                          True
# 1                        False                          True
# 2                        False                          True
# 3                        False                          True
# 4                        False                          True
#
#    MRI/CT Scan Result_Abnormal  MRI/CT Scan Result_Normal  \
# 0                        False                       True
# 1                         True                      False
# 2                        False                      False
# 3                        False                      False
# 4                         True                      False
#
#    MRI/CT Scan Result_Not Done  Seizure Type_Absence  Seizure Type_Focal  \
# 0                        False                 False               False
# 1                        False                 False               False
# 2                         True                 False                True
# 3                         True                 False               False
# 4                        False                 False               False
#
#    Seizure Type_Generalized  Seizure Type_Tonic-Clonic  \
# 0                     False                       True
# 1                     False                       True
# 2                     False                      False
# 3                     False                       True
# 4                     False                       True
#
#    Aura Before Seizure_No  Aura Before Seizure_Yes  Loss of Consciousness_No  \
# 0                    True                    False                     False
# 1                   False                     True                      True
# 2                   False                     True                     False
# 3                    True                    False                     False
# 4                   False                     True                     False
#
#    Loss of Consciousness_Yes  Muscle Stiffness_No  Muscle Stiffness_Yes  \
# 0                       True                 True                 False
# 1                      False                False                  True
# 2                       True                 True                 False
# 3                       True                False                  True
# 4                       True                 True                 False
#
#    Jerky Movements_No  Jerky Movements_Yes  Postictal Confusion_No  \
# 0               False                 True                   False
# 1               False                 True                    True
# 2               False                 True                   False
# 3               False                 True                   False
# 4               False                 True                   False
#
#    Postictal Confusion_Yes  Blank Stare Episodes_No  Blank Stare Episodes_Yes  \
# 0                     True                     True                     False
# 1                    False                    False                      True
# 2                     True                    False                      True
# 3                     True                     True                     False
# 4                     True                    False                      True
#
#    Eye Rolling_No  Eye Rolling_Yes  Stress or Anxiety Before Episode_No  \
# 0           False             True                                False
# 1           False             True                                False
# 2            True            False                                False
# 3            True            False                                False
# 4            True            False                                False
#
#    Stress or Anxiety Before Episode_Yes  Lack of Sleep Before Episode_No  \
# 0                                  True                            False
# 1                                  True                             True
# 2                                  True                            False
# 3                                  True                             True
# 4                                  True                            False
#
#    Lack of Sleep Before Episode_Yes  Flashing Lights Sensitivity_No  \
# 0                              True                           False
# 1                             False                            True
# 2                              True                           False
# 3                             False                            True
# 4                              True                           False
#
#    Flashing Lights Sensitivity_Yes  Loud Sound Sensitivity_No  \
# 0                             True                      False
# 1                            False                      False
# 2                             True                      False
# 3                            False                      False
# 4                             True                       True
#
#    Loud Sound Sensitivity_Yes  Missed Medication_No  Missed Medication_Yes  \
# 0                        True                  True                  False
# 1                        True                 False                   True
# 2                        True                  True                  False
# 3                        True                  True                  False
# 4                       False                  True                  False
#
#    Family History of Epilepsy_No  Family History of Epilepsy_Yes  \
# 0                           True                           False
# 1                          False                            True
# 2                           True                           False
# 3                          False                            True
# 4                          False                            True
#
#    Head Injury History_No  Head Injury History_Yes  Brain Tumor_No  \
# 0                    True                    False            True
# 1                    True                    False            True
# 2                    True                    False            True
# 3                    True                    False           False
# 4                    True                    False            True
#
#    Brain Tumor_Yes  History of Stroke_No  History of Stroke_Yes  \
# 0            False                  True                  False
# 1            False                  True                  False
# 2            False                  True                  False
# 3             True                  True                  False
# 4            False                  True                  False
#
#    Genetic Disorder_No  Genetic Disorder_Yes  \
# 0                 True                 False
# 1                 True                 False
# 2                 True                 False
# 3                 True                 False
# 4                 True                 False
#
#    Developmental Delay (in Children)_No  Developmental Delay (in Children)_Yes
# 0                                 False                                   True
# 1                                  True                                  False
# 2                                  True                                  False
# 3                                  True                                  False
# 4                                  True                                  False

# %%
pd.reset_option('display.max_columns')

# %%
dementia.head()
# Out:
#          Group  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF  M/F_F  M/F_M
# 0  Nondemented   87    14  2.0  27.0  0.0  1987  0.696  0.883  False   True
# 1  Nondemented   88    14  2.0  30.0  0.0  2004  0.681  0.876  False   True
# 2  Nondemented   88    18  3.0  28.0  0.0  1215  0.710  1.444   True  False
# 3  Nondemented   90    18  3.0  27.0  0.0  1200  0.718  1.462   True  False
# 4  Nondemented   80    12  4.0  28.0  0.0  1689  0.712  1.039  False   True

# %% [markdown]
# # Data Science Problems

# %% [markdown]
# In this section, we will solve two classification problems. The problems are:
# 1. Epilepsy Type Classification with the Epilepsy Dataset
# 2. Dementia Group Classification with the Dementia Dataset
#
# The Epilepsy Classification is a binary classification which consist of labels Focal and Generalised. The Dementia Classification is a multiclass classification which has three labels, non-demented, demented and converted.
#
# The machine learning models that will be used are Decision Tree and Logistic Regression The training steps are documented below. This includes validation strategy and evaluation methods. We will start with Decision Tree and move on with Logistic Regression

# %% [markdown]
# # Prepare data

# %% [markdown]
# ## Epilepsy Dataset

# %%
# get features data
X_epi = epilepsy.drop('Epilepsy Type', axis=1)
# get labels
y_epi = epilepsy['Epilepsy Type']

# %%
X_epi.head()
# Out:
#    Age  Weight  Height  Seizure Frequency  Seizure Duration  Gender_Female  \
# 0   15    48.3   168.2                  1                60          False
# 1   36    44.8   156.2                  3                30           True
# 2   32    70.4   180.4                  0                60           True
# 3   29    54.5   161.7                  1                60          False
# 4   18    62.1   168.0                  1                30          False
#
#    Gender_Male  Gender_Other  Medication Status_Not on Medication  \
# 0         True         False                                False
# 1        False         False                                False
# 2        False         False                                 True
# 3         True         False                                False
# 4         True         False                                False
#
#    Medication Status_On Medication  ...  Head Injury History_No  \
# 0                             True  ...                    True
# 1                             True  ...                    True
# 2                            False  ...                    True
# 3                             True  ...                    True
# 4                             True  ...                    True
#
#    Head Injury History_Yes  Brain Tumor_No  Brain Tumor_Yes  \
# 0                    False            True            False
# 1                    False            True            False
# 2                    False            True            False
# 3                    False           False             True
# 4                    False            True            False
#
#    History of Stroke_No  History of Stroke_Yes  Genetic Disorder_No  \
# 0                  True                  False                 True
# 1                  True                  False                 True
# 2                  True                  False                 True
# 3                  True                  False                 True
# 4                  True                  False                 True
#
#    Genetic Disorder_Yes  Developmental Delay (in Children)_No  \
# 0                 False                                 False
# 1                 False                                  True
# 2                 False                                  True
# 3                 False                                  True
# 4                 False                                  True
#
#    Developmental Delay (in Children)_Yes
# 0                                   True
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
# [5 rows x 57 columns]

# %%
# check shape of data 
print(f'data: {X_epi.shape}, label: {y_epi.shape}')
# Out:
# data: (621, 57), label: (621,)

# %%
X_train_epilepsy, X_test_epilepsy, y_train_epilepsy, y_test_epilepsy = train_test_split(X_epi, y_epi, test_size = 0.2, random_state = 0, stratify = y_epi)

# %%
# check shape of train and test data set 
print(f'X_train\t: {X_train_epilepsy.shape}, y_train\t: {y_train_epilepsy.shape}\nX_test\t: {X_test_epilepsy.shape}, y_test\t: {y_test_epilepsy.shape}')
# Out:
# X_train	: (496, 57), y_train	: (496,)
# X_test	: (125, 57), y_test	: (125,)

# %% [markdown]
# ## Dementia Dataset

# %%
# get features data
X_deme = dementia.iloc[:,1:]
# get labels
y_deme = dementia['Group']

# %%
# check shape of data 
print(f'data: {X_deme.shape}, label: {y_deme.shape}')
# Out:
# data: (354, 10), label: (354,)

# %%
X_train_dementia, X_test_dementia, y_train_dementia, y_test_dementia = train_test_split(X_deme, y_deme, test_size = 0.2, random_state = 0, stratify = y_deme)

# %%
# check shape of train and test data set 
print(f'X_train\t: {X_train_dementia.shape}, y_train\t: {y_train_dementia.shape}\nX_test\t: {X_test_dementia.shape}, y_test\t: {y_test_dementia.shape}')
# Out:
# X_train	: (283, 10), y_train	: (283,)
# X_test	: (71, 10), y_test	: (71,)

# %% [markdown]
# # Decision Tree

# %% [markdown]
# ## Finding best parameters using cross validation
# To prevent overfitting which is common for a decision tree, parameters
# - "max_depth"
# - "min_samples_split"
# - "min_samples_leaf"
#
# will be fine tuned. To find the best set of parameters, the best average score across a Stratified 10-fold cross validation will be considered and unique pairs of {"max_depth", "min_sample_split", "min_samples_leaf"} will be used.
#
# Parameter criterion and max_features is set to default which uses 'gini impurity' and the square root of total no. of features respectively[1]. max_features is set to default because sqrt(16) = 4 which is 25% of the total no. of features in the dry bean dataset. The recommendation is to check up to 30-40%[2].
#
# - [1] https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# - [2] Practical data science week 4 slides

# %% [markdown]
# ## Define a function to find best parameters for decision tree

# %%
def find_best_params_DT(X_train, y_train):
    # set of values for each parameter
    max_depth_vals = [5, 7, 10, 12, 15, 17]
    min_samples_split_vals = [2, 5, 10, 20, 50, 100]
    min_samples_leaf_vals = [1, 2, 3, 5, 10, 20]
    
    max_depth_his = list()
    min_samples_his = list()
    min_leafs_his = list()
    corr_avg = list() 
    
    for max_depth in max_depth_vals:
        for min_sample in min_samples_split_vals: 
            for min_leaf in min_samples_leaf_vals: 
                acc_scores = list() 
    
                # instance of Decision Tree for each parameter set
                dt_clf = DecisionTreeClassifier(max_depth = max_depth, min_samples_split = min_sample, min_samples_leaf = min_leaf)
                
                # get average scores of each k fold 
                acc_scores = cross_val_score(dt_clf, X_train, y_train, cv = 10, scoring = 'accuracy')
                
                # find average score across all folds 
                avg_score = acc_scores.mean()
        
                print(f'With max_depth={max_depth}, min_samples_split={min_sample}, and min_samples_leaf={min_leaf}, the average accurary is {avg_score}')
                
                max_depth_his.append(max_depth)
                min_samples_his.append(min_sample)
                min_leafs_his.append(min_leaf)
                corr_avg.append(avg_score)
    
    return max_depth_his, min_samples_his, min_leafs_his, corr_avg

# %% [markdown]
# ## Epilepsy Type Classification

# %%
max_depth_his, min_samples_his, min_leafs_his, corr_avg = find_best_params_DT(X_train_epilepsy, y_train_epilepsy)
# Out:
# With max_depth=5, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8930204081632652
# With max_depth=5, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8829795918367347
# With max_depth=5, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8849387755102042
# With max_depth=5, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=5, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=5, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=5, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8909795918367346
# With max_depth=5, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8869795918367348
# With max_depth=5, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8869387755102041
# With max_depth=5, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=5, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=5, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9111836734693879
# With max_depth=5, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869387755102041
# With max_depth=5, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.882938775510204
# With max_depth=5, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8869387755102041
# With max_depth=5, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.878938775510204
# With max_depth=5, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=5, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=5, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.874938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=5, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9091836734693878
# With max_depth=5, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8829795918367347
# With max_depth=7, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8829795918367347
# With max_depth=7, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8848979591836734
# With max_depth=7, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=7, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=7, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9091836734693877
# With max_depth=7, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8828979591836736
# With max_depth=7, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8849387755102042
# With max_depth=7, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8849387755102042
# With max_depth=7, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.878938775510204
# With max_depth=7, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=7, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=7, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8849795918367347
# With max_depth=7, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8849795918367347
# With max_depth=7, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8930204081632654
# With max_depth=7, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8829795918367346
# With max_depth=7, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8891020408163264
# With max_depth=7, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=7, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=7, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8971020408163264
# With max_depth=7, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9091836734693877
# With max_depth=7, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8949387755102041
# With max_depth=10, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8830204081632653
# With max_depth=10, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8889795918367348
# With max_depth=10, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.878938775510204
# With max_depth=10, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8971020408163264
# With max_depth=10, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9071428571428571
# With max_depth=10, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8829795918367347
# With max_depth=10, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8809795918367348
# With max_depth=10, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8850204081632652
# With max_depth=10, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8789387755102039
# With max_depth=10, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=10, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=10, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8829795918367346
# With max_depth=10, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8849795918367347
# With max_depth=10, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8910204081632654
# With max_depth=10, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=10, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=10, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=10, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=10, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=10, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=10, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=10, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=10, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=10, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8889795918367348
# With max_depth=12, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.880857142857143
# With max_depth=12, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.882938775510204
# With max_depth=12, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=12, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=12, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=12, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8848979591836734
# With max_depth=12, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=12, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.882938775510204
# With max_depth=12, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=12, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=12, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=12, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869795918367348
# With max_depth=12, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8849795918367347
# With max_depth=12, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8890204081632653
# With max_depth=12, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=12, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=12, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=12, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8769387755102039
# With max_depth=12, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.872938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8971020408163264
# With max_depth=12, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9132653061224489
# With max_depth=12, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8971020408163266
# With max_depth=15, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8870204081632653
# With max_depth=15, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8788979591836735
# With max_depth=15, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8829795918367346
# With max_depth=15, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=15, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=15, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8868979591836735
# With max_depth=15, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8810612244897958
# With max_depth=15, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8849795918367347
# With max_depth=15, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=15, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8971020408163264
# With max_depth=15, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=15, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869795918367348
# With max_depth=15, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8809795918367346
# With max_depth=15, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8950204081632653
# With max_depth=15, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=15, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=15, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9152653061224492
# With max_depth=15, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.872938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8769387755102039
# With max_depth=15, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=15, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=15, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.895061224489796
# With max_depth=17, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8890612244897959
# With max_depth=17, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8869795918367347
# With max_depth=17, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=17, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=17, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=17, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8909795918367346
# With max_depth=17, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8810204081632653
# With max_depth=17, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8829795918367347
# With max_depth=17, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.882938775510204
# With max_depth=17, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=17, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=17, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869795918367348
# With max_depth=17, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8869795918367348
# With max_depth=17, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8950204081632653
# With max_depth=17, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=17, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=17, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9091836734693877
# With max_depth=17, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8769387755102039
# With max_depth=17, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.872938775510204
# With max_depth=17, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=17, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=17, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=17, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9152653061224492
# With max_depth=17, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959

# %%
max_ind = np.argmax(corr_avg)
best_max_depth = max_depth_his[max_ind]
best_min_samples_split = min_samples_his[max_ind]
best_min_leafs = min_leafs_his[max_ind]

print(f'The best acc is {corr_avg[max_ind]} with parameters:\n- max_depth\t\t=\t{best_max_depth}\n- min_samples_split\t=\t{best_min_samples_split}\n- min_samples_leaf\t=\t{best_min_leafs}')
# Out:
# The best acc is 0.9152653061224492 with parameters:
# - max_depth		=	15
# - min_samples_split	=	10
# - min_samples_leaf	=	20

# %% [markdown]
# ### Feature Selection/Hill climbing

# %% [markdown]
# Given Epilepsy dataset has 29 features, we can find the best set of features to train the final model along with the best set of paramters found. This is done using the hill climbing algorithm. Hill climbing randomly selects a feature from the dataset and adds it to a list where the features in the list is used to train the model. If the newly added feature improves the accuracy of the model, it is kept in the list. If it decreases or doesn't improve the accuracy, it is removed from the list.
#
# This method works by having 19 different lists with range of values from 0 to n which represents each feature in the dataset and each list is randomly shuffled using 1 to 19 as the random_state parameter of the shuffle function[1]. It will go through all 19 of them to build the list that gives the best accuracy. This list will then be used to train the final model. Note that shuffle function may provide different shuffled lists when a kernel restarts. This affects the starting point and only moves towards a local minima rather than a global minimum.
#
# - [1] https://scikit-learn.org/stable/modules/generated/sklearn.utils.shuffle.html

# %%
feas_set = list() 
scores = list() 

for i in range(1,20): 
    # to keep best features and score from them
    keep_feas_ind = []
    best_score = 0.0 
    
    # 16 features in epilepsy dataset
    fea_num = 29
    # create a new random list from the range of 1 to 15 by using a new random_state number 
    random_col_ind = shuffle(range(0,fea_num), random_state = i)

    print(f'random_state = {i}, col_ids = {random_col_ind}')
    for j in range(0, fea_num): 
        # add index of currently selected feature to the list
        keep_feas_ind.append(random_col_ind[j])
    
        # get bean features based off index listed in the list
        X_h = X_epi.iloc[:,keep_feas_ind]
    
        # create new train test split based off features in that list 
        X_train_h, X_test_h, y_train_h, y_test_h = train_test_split(X_h, y_epi, test_size = 0.2, random_state = 0, stratify = y_epi)
    
        # create instace of KNN with the best k and p value
        dt_clf = DecisionTreeClassifier(max_depth = best_max_depth, min_samples_split = best_min_samples_split, min_samples_leaf = best_min_leafs)
    
        # fit data into model 
        dt_fit = dt_clf.fit(X_train_h, y_train_h)
        
        # test model with test dataset and get the score - accurary 
        dt_score = dt_fit.score(X_test_h, y_test_h)
    
        # if newly added feature doesn't improve the model based off score, remove it from list 
        if (dt_score < best_score) or (dt_score == best_score): 
            keep_feas_ind.remove(random_col_ind[j])
        else: 
            # else keep it and update the new best score
            best_score = dt_score
            print("Score with " + str(len(keep_feas_ind)) + " Selected features: " + str(dt_score))

    feas_set.append(keep_feas_ind)
    scores.append(best_score)
    print(keep_feas_ind)
    print()
# Out:
# random_state = 1, col_ids = [14, 21, 18, 20, 25, 19, 3, 10, 23, 22, 4, 2, 24, 6, 17, 13, 7, 26, 1, 16, 0, 15, 28, 27, 9, 8, 12, 11, 5]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.888
# [14, 18]
#
# random_state = 2, col_ids = [1, 0, 14, 9, 20, 24, 16, 6, 3, 19, 27, 26, 12, 4, 10, 5, 21, 17, 2, 7, 25, 23, 18, 11, 22, 28, 13, 15, 8]
# Score with 1 Selected features: 0.56
# Score with 2 Selected features: 0.616
# Score with 3 Selected features: 0.64
# Score with 4 Selected features: 0.688
# Score with 5 Selected features: 0.896
# [1, 0, 20, 24, 19]
#
# random_state = 3, col_ids = [18, 17, 12, 26, 15, 16, 13, 2, 1, 23, 14, 4, 22, 6, 7, 5, 20, 9, 11, 28, 19, 21, 0, 8, 27, 3, 25, 24, 10]
# Score with 1 Selected features: 0.888
# [18]
#
# random_state = 4, col_ids = [11, 21, 27, 15, 20, 24, 17, 25, 19, 0, 3, 16, 10, 6, 12, 2, 4, 22, 13, 7, 9, 18, 28, 8, 1, 5, 23, 14, 26]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.608
# Score with 3 Selected features: 0.728
# Score with 4 Selected features: 0.824
# Score with 5 Selected features: 0.888
# Score with 6 Selected features: 0.92
# [11, 21, 27, 24, 18, 1]
#
# random_state = 5, col_ids = [11, 28, 24, 21, 26, 10, 2, 13, 25, 20, 27, 0, 17, 5, 1, 12, 19, 18, 23, 7, 4, 8, 9, 16, 22, 6, 15, 14, 3]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.728
# Score with 3 Selected features: 0.832
# Score with 4 Selected features: 0.888
# Score with 5 Selected features: 0.896
# [11, 28, 24, 18, 4]
#
# random_state = 6, col_ids = [0, 27, 26, 6, 14, 18, 7, 5, 21, 17, 2, 8, 25, 4, 12, 19, 22, 23, 11, 1, 16, 24, 15, 13, 28, 20, 3, 9, 10]
# Score with 1 Selected features: 0.512
# Score with 2 Selected features: 0.664
# Score with 3 Selected features: 0.888
# Score with 4 Selected features: 0.896
# [0, 27, 18, 23]
#
# random_state = 7, col_ids = [2, 17, 1, 9, 11, 5, 18, 23, 24, 28, 12, 13, 16, 0, 27, 6, 26, 20, 10, 21, 8, 14, 7, 19, 3, 22, 25, 4, 15]
# Score with 1 Selected features: 0.52
# Score with 2 Selected features: 0.528
# Score with 3 Selected features: 0.536
# Score with 4 Selected features: 0.888
# [2, 11, 5, 18]
#
# random_state = 8, col_ids = [24, 0, 7, 18, 14, 4, 28, 1, 21, 6, 27, 11, 2, 15, 25, 22, 12, 10, 26, 13, 16, 23, 19, 8, 5, 9, 17, 20, 3]
# Score with 1 Selected features: 0.704
# Score with 2 Selected features: 0.888
# Score with 3 Selected features: 0.896
# [24, 18, 4]
#
# random_state = 9, col_ids = [5, 9, 15, 4, 3, 7, 18, 19, 6, 2, 12, 13, 16, 10, 27, 11, 14, 0, 23, 17, 8, 20, 25, 1, 26, 24, 22, 21, 28]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.888
# [5, 18]
#
# random_state = 10, col_ids = [14, 7, 5, 2, 26, 20, 12, 13, 18, 1, 22, 6, 11, 23, 19, 3, 27, 21, 10, 25, 28, 8, 24, 16, 17, 0, 15, 4, 9]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.888
# [14, 18]
#
# random_state = 11, col_ids = [15, 8, 6, 26, 3, 11, 14, 21, 9, 5, 10, 22, 2, 4, 20, 28, 19, 0, 27, 24, 18, 7, 1, 12, 13, 23, 17, 16, 25]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.648
# Score with 3 Selected features: 0.664
# Score with 4 Selected features: 0.712
# Score with 5 Selected features: 0.728
# Score with 6 Selected features: 0.92
# [15, 21, 5, 20, 28, 19]
#
# random_state = 12, col_ids = [7, 15, 21, 9, 1, 19, 4, 14, 22, 20, 8, 18, 0, 10, 26, 28, 24, 13, 5, 25, 16, 12, 23, 3, 2, 17, 6, 27, 11]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.648
# Score with 3 Selected features: 0.864
# Score with 4 Selected features: 0.92
# [7, 21, 19, 20]
#
# random_state = 13, col_ids = [21, 15, 25, 1, 24, 8, 7, 28, 17, 22, 0, 19, 4, 11, 9, 26, 13, 5, 14, 23, 3, 12, 20, 2, 6, 27, 10, 16, 18]
# Score with 1 Selected features: 0.648
# Score with 2 Selected features: 0.704
# Score with 3 Selected features: 0.824
# Score with 4 Selected features: 0.888
# [21, 24, 28, 18]
#
# random_state = 14, col_ids = [2, 19, 3, 9, 1, 17, 15, 5, 14, 23, 20, 26, 21, 18, 4, 27, 0, 28, 13, 8, 16, 25, 10, 6, 7, 22, 12, 24, 11]
# Score with 1 Selected features: 0.52
# Score with 2 Selected features: 0.752
# Score with 3 Selected features: 0.784
# Score with 4 Selected features: 0.92
# [2, 19, 3, 20]
#
# random_state = 15, col_ids = [16, 14, 26, 27, 19, 18, 1, 2, 28, 6, 3, 25, 22, 9, 4, 20, 10, 24, 13, 17, 15, 11, 7, 0, 23, 5, 12, 21, 8]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.728
# Score with 3 Selected features: 0.888
# [16, 27, 18]
#
# random_state = 16, col_ids = [6, 8, 12, 7, 19, 18, 21, 11, 3, 13, 26, 17, 22, 2, 10, 15, 24, 20, 27, 16, 0, 28, 23, 4, 1, 5, 25, 14, 9]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.8
# Score with 3 Selected features: 0.888
# [6, 19, 18]
#
# random_state = 17, col_ids = [0, 18, 21, 11, 5, 24, 26, 19, 23, 25, 3, 2, 10, 8, 9, 27, 14, 1, 20, 12, 7, 4, 13, 16, 22, 6, 28, 17, 15]
# Score with 1 Selected features: 0.512
# Score with 2 Selected features: 0.888
# Score with 3 Selected features: 0.896
# [0, 18, 24]
#
# random_state = 18, col_ids = [11, 0, 27, 20, 6, 13, 1, 3, 9, 12, 7, 22, 4, 16, 28, 23, 15, 25, 26, 21, 8, 2, 18, 14, 17, 5, 24, 19, 10]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.728
# Score with 3 Selected features: 0.832
# Score with 4 Selected features: 0.888
# [11, 27, 23, 18]
#
# random_state = 19, col_ids = [13, 3, 23, 6, 18, 25, 11, 24, 4, 17, 9, 16, 28, 0, 15, 7, 12, 22, 1, 5, 27, 26, 10, 20, 19, 8, 2, 21, 14]
# Score with 1 Selected features: 0.584
# Score with 2 Selected features: 0.704
# Score with 3 Selected features: 0.888
# Score with 4 Selected features: 0.896
# [13, 23, 18, 4]

# %%
# get feature set with the highest score 
highest_score_ind = np.argmax(scores)
highest_score = scores[highest_score_ind]
best_features_index = feas_set[highest_score_ind]

print(f'The highest score is {highest_score}\nwith features: {X_epi.columns[best_features_index].tolist()}')
# Out:
# The highest score is 0.92
# with features: ['Alcohol or Drug Use_Yes', 'Aura Before Seizure_No', 'Jerky Movements_No', 'Loss of Consciousness_Yes', 'Seizure Type_Focal', 'Weight']

# %%
# select the best features from the cleaned data
X_best_feas = X_epi.iloc[:, best_features_index]

# create new train test split based off best features
X_train_bf, X_test_bf, y_train_bf, y_test_bf = train_test_split(X_best_feas, y_epi, test_size = 0.2, random_state = 0, stratify = y_epi)

# create instace of KNN with the best max_depth, min_samples_split, and min_samples_leaf values
dt_clf = DecisionTreeClassifier(max_depth = best_max_depth, min_samples_split = best_min_samples_split, min_samples_leaf = best_min_leafs)

# fit data into model 
dt_fit = dt_clf.fit(X_train_bf, y_train_bf)

# predict with test data set 
dt_predicted_epilepsy = dt_fit.predict(X_test_bf)

# %% [markdown]
# ## Dementia Type Classification

# %% [markdown]
# ### Find the best parameters

# %%
max_depth_his, min_samples_his, min_leafs_his, corr_avg = find_best_params_DT(X_train_dementia, y_train_dementia)
# Out:
# With max_depth=5, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8620689655172414
# With max_depth=5, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8411330049261083
# With max_depth=5, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8625615763546799
# With max_depth=5, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=5, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=5, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8551724137931036
# With max_depth=5, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8269704433497538
# With max_depth=5, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8625615763546799
# With max_depth=5, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=5, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.887192118226601
# With max_depth=5, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8551724137931036
# With max_depth=5, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8374384236453203
# With max_depth=5, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8516009852216749
# With max_depth=5, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=5, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=5, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8799261083743841
# With max_depth=5, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=5, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=5, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=5, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8729064039408867
# With max_depth=5, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=5, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=5, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=5, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=5, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8448275862068966
# With max_depth=7, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8267241379310345
# With max_depth=7, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8518472906403941
# With max_depth=7, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=7, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8907635467980295
# With max_depth=7, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8445812807881774
# With max_depth=7, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8233990147783252
# With max_depth=7, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8518472906403941
# With max_depth=7, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=7, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8943349753694582
# With max_depth=7, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8586206896551726
# With max_depth=7, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8160098522167489
# With max_depth=7, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8408866995073894
# With max_depth=7, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=7, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=7, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8730295566502463
# With max_depth=7, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=7, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=7, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=7, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8729064039408867
# With max_depth=7, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=7, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=7, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=7, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=7, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8378078817733989
# With max_depth=10, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8124384236453203
# With max_depth=10, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=10, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=10, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8907635467980295
# With max_depth=10, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8270935960591131
# With max_depth=10, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8091133004926109
# With max_depth=10, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=10, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=10, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8907635467980295
# With max_depth=10, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8444581280788178
# With max_depth=10, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8088669950738916
# With max_depth=10, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8408866995073891
# With max_depth=10, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=10, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8764778325123153
# With max_depth=10, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8730295566502463
# With max_depth=10, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=10, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=10, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=10, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=10, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=10, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=10, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=10, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=10, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.827216748768473
# With max_depth=12, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8158866995073893
# With max_depth=12, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=12, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=12, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=12, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8374384236453201
# With max_depth=12, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8161330049261084
# With max_depth=12, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=12, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=12, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=12, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.84064039408867
# With max_depth=12, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8124384236453203
# With max_depth=12, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8408866995073891
# With max_depth=12, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=12, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8836206896551724
# With max_depth=12, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8730295566502463
# With max_depth=12, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=12, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=12, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=12, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=12, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=12, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=12, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=12, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=12, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8483990147783251
# With max_depth=15, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.823152709359606
# With max_depth=15, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=15, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=15, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8729064039408867
# With max_depth=15, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8233990147783251
# With max_depth=15, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.816256157635468
# With max_depth=15, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=15, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=15, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8764778325123153
# With max_depth=15, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8407635467980296
# With max_depth=15, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8160098522167487
# With max_depth=15, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8373152709359607
# With max_depth=15, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=15, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=15, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8799261083743841
# With max_depth=15, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=15, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=15, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=15, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=15, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=15, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=15, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=15, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=15, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8450738916256159
# With max_depth=17, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8301724137931036
# With max_depth=17, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=17, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=17, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8907635467980295
# With max_depth=17, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.826847290640394
# With max_depth=17, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8126847290640395
# With max_depth=17, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8482758620689654
# With max_depth=17, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=17, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=17, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8477832512315271
# With max_depth=17, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8160098522167487
# With max_depth=17, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8408866995073891
# With max_depth=17, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8729064039408867
# With max_depth=17, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8800492610837438
# With max_depth=17, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8799261083743841
# With max_depth=17, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8482758620689657
# With max_depth=17, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8589901477832512
# With max_depth=17, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.8801724137931034
# With max_depth=17, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8764778325123153
# With max_depth=17, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8832512315270936
# With max_depth=17, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8619458128078819
# With max_depth=17, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8726600985221676
# With max_depth=17, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8903940886699507
# With max_depth=17, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8903940886699507

# %%
max_ind = np.argmax(corr_avg)
best_max_depth = max_depth_his[max_ind]
best_min_samples_split = min_samples_his[max_ind]
best_min_leafs = min_leafs_his[max_ind]

print(f'The best acc is {corr_avg[max_ind]} with parameters:\n- max_depth\t\t=\t{best_max_depth}\n- min_samples_split\t=\t{best_min_samples_split}\n- min_samples_leaf\t=\t{best_min_leafs}')
# Out:
# The best acc is 0.8943349753694582 with parameters:
# - max_depth		=	7
# - min_samples_split	=	5
# - min_samples_leaf	=	10

# %% [markdown]
# Given there are only 10 features in the Dementia dataset, hill climbing will not be used here.

# %% [markdown]
# ### Train with best set of parameters

# %%
# create instace of KNN with the best max_depth, min_samples_split, and min_samples_leaf values
dt_clf = DecisionTreeClassifier(max_depth = best_max_depth, min_samples_split = best_min_samples_split, min_samples_leaf = best_min_leafs)

# fit data into model 
dt_fit = dt_clf.fit(X_train_dementia, y_train_dementia)

# predict with test data set 
dt_predicted_dementia = dt_fit.predict(X_test_dementia)

# %% [markdown]
# ## Evaluation with classification report

# %% [markdown]
# ### Epilepsy Classification

# %%
# confusion matrix
print(confusion_matrix(y_test_epilepsy, dt_predicted_epilepsy))

print(classification_report(y_test_epilepsy, dt_predicted_epilepsy))
# Out:
# [[49  3]
#  [ 7 66]]
#               precision    recall  f1-score   support
#
#        Focal       0.88      0.94      0.91        52
#  Generalised       0.96      0.90      0.93        73
#
#     accuracy                           0.92       125
#    macro avg       0.92      0.92      0.92       125
# weighted avg       0.92      0.92      0.92       125

# %% [markdown]
# ### Dementia Classification

# %%
# confusion matrix
print(confusion_matrix(y_test_dementia, dt_predicted_dementia))

print(classification_report(y_test_dementia, dt_predicted_dementia))
# Out:
# [[ 2  1  4]
#  [ 1 25  0]
#  [ 0  1 37]]
#               precision    recall  f1-score   support
#
#    Converted       0.67      0.29      0.40         7
#     Demented       0.93      0.96      0.94        26
#  Nondemented       0.90      0.97      0.94        38
#
#     accuracy                           0.90        71
#    macro avg       0.83      0.74      0.76        71
# weighted avg       0.89      0.90      0.89        71

# %% [markdown]
# #### ERROR NOTE:

# %% [markdown]
# Zero division warning error because the model has not classified a Converted correctly.

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Finding best parameters with LogisticRegressionCV
# LogisticRegressionCV parameters such as loss function and regularisation will be discussed here. Sklearn's logistic regression uses a multinomial cross-entropy loss as the loss function for a multiclass problem such as the Dementia Classificaion.
#
# The parameters that I will be setting:
# 1. l1_ratio which is a regularisor that adds penalty to the loss function. I will be using the L2 regularisation
# 2. solver - solver is the optimisation method to reduced the loss function. I will be using 'lbfgs'
# 3. max_iter - maximum iteration allowed for optimisation solver to converge
# 4. cv - number of cross validation fold. This will be explained below.
#
# Instead of specifying a set of predefined parameters with the cross_val_score method to find the best parameters, sklearn LogisticRegressionCV performs a stratifiedKFold cross validation internally to select the best 'C' parameter for us. This parameter is the inverse regularisation
#
# - [1] https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegressionCV.html

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegressionCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Epilepsy Dataset

# %%
lr_e = LogisticRegressionCV(solver='lbfgs', max_iter=800, cv=10, l1_ratios=0)

# %%
lr_e.fit(X_train_epilepsy, y_train_epilepsy)
# Out:
# /opt/anaconda3/envs/py3_12_7/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1780: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# /opt/anaconda3/envs/py3_12_7/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1823: FutureWarning: The fitted attributes of LogisticRegressionCV will be simplified in scikit-learn 1.10 to remove redundancy. Set`use_legacy_attributes=False` to enable the new behavior now, or set it to `True` to silence this warning during the transition period while keeping the deprecated behavior for the time being. The default value of use_legacy_attributes will change from True to False in scikit-learn 1.10. See the docstring of LogisticRegressionCV for more details.
#   warnings.warn(
# LogisticRegressionCV(max_iter=800)

# %%
y_pred_e = lr_e.predict(X_test_epilepsy)
y_prob_e = lr_e.predict_proba(X_test_epilepsy)

# %%
y_prob_e.shape
y_prob_e
# Out:
# array([[9.93837425e-01, 6.16257540e-03],
#        [2.25729262e-02, 9.77427074e-01],
#        [9.08120736e-01, 9.18792635e-02],
#        [9.55578469e-01, 4.44215308e-02],
#        [9.96842060e-01, 3.15793957e-03],
#        [9.35660154e-01, 6.43398460e-02],
#        [9.49075262e-01, 5.09247381e-02],
#        [7.18828586e-03, 9.92811714e-01],
#        [9.91458703e-01, 8.54129689e-03],
#        [1.62599371e-01, 8.37400629e-01],
#        [1.18937971e-01, 8.81062029e-01],
#        [6.81406838e-02, 9.31859316e-01],
#        [4.22442330e-01, 5.77557670e-01],
#        [1.26215041e-01, 8.73784959e-01],
#        [9.24286383e-01, 7.57136169e-02],
#        [1.60379090e-02, 9.83962091e-01],
#        [9.85412405e-01, 1.45875952e-02],
#        [6.38592573e-02, 9.36140743e-01],
#        [2.61477663e-02, 9.73852234e-01],
#        [8.39623879e-01, 1.60376121e-01],
#        [7.76646736e-02, 9.22335326e-01],
#        [9.43650479e-01, 5.63495205e-02],
#        [9.94169109e-01, 5.83089113e-03],
#        [1.48529847e-02, 9.85147015e-01],
#        [9.89382609e-01, 1.06173911e-02],
#        [2.36522409e-01, 7.63477591e-01],
#        [9.79421346e-01, 2.05786536e-02],
#        [8.50381959e-01, 1.49618041e-01],
#        [6.85926797e-03, 9.93140732e-01],
#        [9.90268825e-01, 9.73117548e-03],
#        [9.94446379e-01, 5.55362072e-03],
#        [7.89132486e-02, 9.21086751e-01],
#        [4.71635825e-02, 9.52836417e-01],
#        [3.70537050e-02, 9.62946295e-01],
#        [9.76265247e-01, 2.37347530e-02],
#        [1.09803318e-01, 8.90196682e-01],
#        [4.11251870e-02, 9.58874813e-01],
#        [1.84835053e-01, 8.15164947e-01],
#        [6.95758748e-03, 9.93042413e-01],
#        [9.98304243e-01, 1.69575688e-03],
#        [9.92579089e-01, 7.42091132e-03],
#        [4.57837013e-02, 9.54216299e-01],
#        [8.04693522e-02, 9.19530648e-01],
#        [3.42844335e-01, 6.57155665e-01],
#        [2.09940555e-02, 9.79005945e-01],
#        [1.06793839e-02, 9.89320616e-01],
#        [9.91353459e-01, 8.64654110e-03],
#        [9.70694924e-01, 2.93050758e-02],
#        [1.80776608e-02, 9.81922339e-01],
#        [1.14433630e-02, 9.88556637e-01],
#        [9.55376369e-01, 4.46236308e-02],
#        [4.27694405e-01, 5.72305595e-01],
#        [9.67383941e-01, 3.26160594e-02],
#        [1.97695164e-01, 8.02304836e-01],
#        [8.57710936e-01, 1.42289064e-01],
#        [8.40727471e-03, 9.91592725e-01],
#        [1.62411358e-02, 9.83758864e-01],
#        [9.83192460e-01, 1.68075402e-02],
#        [3.01183253e-02, 9.69881675e-01],
#        [5.27715058e-03, 9.94722849e-01],
#        [9.49691002e-01, 5.03089981e-02],
#        [7.09774293e-01, 2.90225707e-01],
#        [2.11523219e-02, 9.78847678e-01],
#        [1.38245051e-02, 9.86175495e-01],
#        [9.15768716e-01, 8.42312844e-02],
#        [1.14450447e-01, 8.85549553e-01],
#        [9.91065268e-03, 9.90089347e-01],
#        [1.34964389e-02, 9.86503561e-01],
#        [9.61700680e-01, 3.82993200e-02],
#        [1.00533503e-01, 8.99466497e-01],
#        [4.19909672e-02, 9.58009033e-01],
#        [7.69252108e-03, 9.92307479e-01],
#        [9.87184377e-01, 1.28156232e-02],
#        [3.49010617e-01, 6.50989383e-01],
#        [3.44760495e-02, 9.65523950e-01],
#        [3.71252071e-02, 9.62874793e-01],
#        [2.03544034e-02, 9.79645597e-01],
#        [2.80076143e-02, 9.71992386e-01],
#        [9.50954051e-03, 9.90490459e-01],
#        [3.79280272e-03, 9.96207197e-01],
#        [9.78252923e-02, 9.02174708e-01],
#        [9.99386857e-01, 6.13143281e-04],
#        [6.94908730e-02, 9.30509127e-01],
#        [1.38661681e-03, 9.98613383e-01],
#        [1.36207356e-01, 8.63792644e-01],
#        [4.58935926e-02, 9.54106407e-01],
#        [2.95972019e-02, 9.70402798e-01],
#        [4.52389737e-03, 9.95476103e-01],
#        [3.80646525e-01, 6.19353475e-01],
#        [9.53158974e-01, 4.68410265e-02],
#        [3.66545011e-02, 9.63345499e-01],
#        [1.93632989e-02, 9.80636701e-01],
#        [4.41300846e-02, 9.55869915e-01],
#        [7.96495839e-01, 2.03504161e-01],
#        [9.89753783e-01, 1.02462171e-02],
#        [8.74351018e-02, 9.12564898e-01],
#        [2.21339683e-01, 7.78660317e-01],
#        [9.45285900e-01, 5.47141004e-02],
#        [1.55532918e-02, 9.84446708e-01],
#        [3.16596597e-02, 9.68340340e-01],
#        [9.30191360e-01, 6.98086399e-02],
#        [4.95567321e-03, 9.95044327e-01],
#        [8.44301442e-01, 1.55698558e-01],
#        [9.80205117e-01, 1.97948825e-02],
#        [7.81267603e-01, 2.18732397e-01],
#        [3.16556113e-02, 9.68344389e-01],
#        [9.60004228e-01, 3.99957718e-02],
#        [9.97936311e-01, 2.06368933e-03],
#        [7.50079766e-01, 2.49920234e-01],
#        [8.25843964e-03, 9.91741560e-01],
#        [1.55407073e-01, 8.44592927e-01],
#        [5.33833565e-02, 9.46616643e-01],
#        [9.02605581e-01, 9.73944186e-02],
#        [9.60595427e-01, 3.94045734e-02],
#        [4.52708051e-03, 9.95472919e-01],
#        [5.93034103e-01, 4.06965897e-01],
#        [9.90740254e-01, 9.25974616e-03],
#        [7.03211141e-02, 9.29678886e-01],
#        [9.43297770e-01, 5.67022303e-02],
#        [1.58177469e-02, 9.84182253e-01],
#        [1.99504681e-01, 8.00495319e-01],
#        [5.36882521e-01, 4.63117479e-01],
#        [9.62304691e-01, 3.76953085e-02],
#        [8.05852840e-01, 1.94147160e-01],
#        [2.37539081e-01, 7.62460919e-01]])

# %%
print(f"Accuracy: {accuracy_score(y_test_epilepsy, y_pred_e):.2f}")
print("\nClassification Report:\n", classification_report(y_test_epilepsy, y_pred_e, target_names=epilepsy['Epilepsy Type'].unique()))
# Out:
# Accuracy: 0.90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#  Generalised       0.88      0.87      0.87        52
#        Focal       0.91      0.92      0.91        73
#
#     accuracy                           0.90       125
#    macro avg       0.89      0.89      0.89       125
# weighted avg       0.90      0.90      0.90       125

# %% [markdown]
# ## Dementia Dataset

# %% [markdown]
# After experimenting a few values of max_iter, a minimum of 20,000 iterations were needed for the logisticregression optimisation solver to converge,

# %%
lr_d = LogisticRegression(solver='lbfgs', l1_ratio=0, max_iter=20000, random_state=0)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_dementia)
X_test_scaled = scaler.transform(X_test_dementia)

# %%
lr_d.fit(X_train_scaled, y_train_dementia)
# Out:
# LogisticRegression(l1_ratio=0, max_iter=20000, random_state=0)

# %%
y_pred_d = lr_d.predict(X_test_scaled)
y_prob_d = lr_d.predict_proba(X_test_scaled)

# %%
print(f"Accuracy: {accuracy_score(y_test_dementia, y_pred_d):.2f}")
print("\nClassification Report:\n", classification_report(y_test_dementia, y_pred_d, target_names=dementia.Group.unique()))
# Out:
# Accuracy: 0.90
#
# Classification Report:
#                precision    recall  f1-score   support
#
#  Nondemented       1.00      0.14      0.25         7
#     Demented       0.96      1.00      0.98        26
#    Converted       0.86      0.97      0.91        38
#
#     accuracy                           0.90        71
#    macro avg       0.94      0.71      0.71        71
# weighted avg       0.91      0.90      0.87        71
