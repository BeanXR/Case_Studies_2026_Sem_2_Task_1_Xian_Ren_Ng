# %% [markdown]
# # Load required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Epilepsy Dataset

# %% [markdown]
# # Load Data

# %%
epilepsy = pd.read_csv('./Datasets/epilepsyOriginal.csv', sep= ',', decimal= '.', on_bad_lines = 'error', skip_blank_lines=False)

# %% [markdown]
# # Check if data loaded matches source

# %%
pd.set_option('display.max_columns', None)

# %%
epilepsy.head()
# Out:
#    Age  Gender  Weight  Height  Medication Status Alcohol or Drug Use  \
# 0   15    Male    48.3   168.2      On Medication                 Yes
# 1    4  Female    56.0   174.5      On Medication                  No
# 2   36  Female    44.8   156.2      On Medication                  No
# 3   32  Female    70.4   180.4  Not on Medication                  No
# 4   29    Male    54.5   161.7      On Medication                  No
#
#   EEG Abnormality Detected MRI/CT Scan Result  Seizure Frequency  \
# 0                      Yes             Normal                  1
# 1                      Yes           Abnormal                  1
# 2                      Yes           Abnormal                  3
# 3                      Yes           Not Done                  0
# 4                      Yes           Not Done                  1
#
#    Seizure Duration  Seizure Type Aura Before Seizure Loss of Consciousness  \
# 0                60  Tonic-Clonic                  No                   Yes
# 1                30   Generalized                 Yes                   Yes
# 2                30  Tonic-Clonic                 Yes                    No
# 3                60         Focal                 Yes                   Yes
# 4                60  Tonic-Clonic                  No                   Yes
#
#   Muscle Stiffness Jerky Movements Postictal Confusion Blank Stare Episodes  \
# 0               No             Yes                 Yes                   No
# 1              Yes             Yes                 Yes                   No
# 2              Yes             Yes                  No                  Yes
# 3               No             Yes                 Yes                  Yes
# 4              Yes             Yes                 Yes                   No
#
#   Eye Rolling Stress or Anxiety Before Episode Lack of Sleep Before Episode  \
# 0         Yes                              Yes                          Yes
# 1          No                               No                           No
# 2         Yes                              Yes                           No
# 3          No                              Yes                          Yes
# 4          No                              Yes                           No
#
#   Flashing Lights Sensitivity Loud Sound Sensitivity Missed Medication  \
# 0                         Yes                    Yes                No
# 1                          No                     No                No
# 2                          No                    Yes               Yes
# 3                         Yes                    Yes                No
# 4                          No                    Yes                No
#
#   Family History of Epilepsy Head Injury History Brain Tumor  \
# 0                         No                  No          No
# 1                        Yes                 Yes         Yes
# 2                        Yes                  No          No
# 3                         No                  No          No
# 4                        Yes                  No         Yes
#
#   History of Stroke Genetic Disorder Developmental Delay (in Children)  \
# 0                No               No                               Yes
# 1                No               No                                No
# 2                No               No                                No
# 3                No               No                                No
# 4                No               No                                No
#
#   Epilepsy Type
# 0   Generalized
# 1   Generalized
# 2   Generalized
# 3         Focal
# 4   Generalized

# %%
epilepsy.tail()
# Out:
#      Age  Gender  Weight  Height  Medication Status Alcohol or Drug Use  \
# 719   18    Male    62.8   168.5      On Medication                  No
# 720   36  Female    69.2   168.3      On Medication                  No
# 721   54  Female    73.9   168.0      On Medication                  No
# 722   44  Female    55.1   171.7  Not on Medication                  No
# 723   65  Female    50.9   169.4      On Medication                  No
#
#     EEG Abnormality Detected MRI/CT Scan Result  Seizure Frequency  \
# 719                      Yes           Abnormal                  1
# 720                      Yes           Abnormal                  3
# 721                      Yes             Normal                  2
# 722                      Yes           Not Done                  0
# 723                      Yes           Abnormal                 10
#
#      Seizure Duration  Seizure Type Aura Before Seizure Loss of Consciousness  \
# 719                60  Tonic-Clonic                  No                   Yes
# 720                30   Generalized                 Yes                    No
# 721                90         Focal                 Yes                   Yes
# 722                60         Focal                  No                   Yes
# 723               120         Focal                 Yes                   Yes
#
#     Muscle Stiffness Jerky Movements Postictal Confusion Blank Stare Episodes  \
# 719              Yes             Yes                 Yes                   No
# 720               No              No                 Yes                  Yes
# 721               No             Yes                 Yes                   No
# 722              Yes              No                 Yes                   No
# 723              Yes             Yes                  No                  Yes
#
#     Eye Rolling Stress or Anxiety Before Episode Lack of Sleep Before Episode  \
# 719         Yes                              Yes                          Yes
# 720          No                              Yes                          Yes
# 721          No                              Yes                           No
# 722         Yes                              Yes                           No
# 723          No                              Yes                          Yes
#
#     Flashing Lights Sensitivity Loud Sound Sensitivity Missed Medication  \
# 719                         Yes                     No               Yes
# 720                         Yes                     No                No
# 721                         Yes                     No                No
# 722                         Yes                     No                No
# 723                          No                    Yes               Yes
#
#     Family History of Epilepsy Head Injury History Brain Tumor  \
# 719                         No                  No          No
# 720                         No                  No          No
# 721                         No                 Yes          No
# 722                         No                 Yes          No
# 723                         No                 Yes          No
#
#     History of Stroke Genetic Disorder Developmental Delay (in Children)  \
# 719                No               No                                No
# 720                No               No                                No
# 721                No               No                                No
# 722                No               No                                No
# 723                No               No                                No
#
#     Epilepsy Type
# 719   Generalized
# 720   Generalized
# 721         Focal
# 722         Focal
# 723         Focal

# %% [markdown]
# The number of rows and columns matches csv file.

# %%
pd.reset_option('display.max_columns')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Duplicated Rows
#
# using .duplicated function to check duplicated rows and there are none.

# %%
duplicate_mask = epilepsy.duplicated()
print("No. of duplicated rows:",duplicate_mask.sum())
# Out:
# No. of duplicated rows: 0

# %% [markdown]
# ## Check data types
# using dtypes and value_counts(), we can check the data types in this dataset and its corresponding count. This dataset consists of 25 string/text, 2 integer, and 2 float variables.

# %%
epilepsy.dtypes
# Out:
# Age                                    int64
# Gender                                   str
# Weight                               float64
# Height                               float64
# Medication Status                        str
# Alcohol or Drug Use                      str
# EEG Abnormality Detected                 str
# MRI/CT Scan Result                       str
# Seizure Frequency                      int64
# Seizure Duration                       int64
# Seizure Type                             str
# Aura Before Seizure                      str
# Loss of Consciousness                    str
# Muscle Stiffness                         str
# Jerky Movements                          str
# Postictal Confusion                      str
# Blank Stare Episodes                     str
# Eye Rolling                              str
# Stress or Anxiety Before Episode         str
# Lack of Sleep Before Episode             str
# Flashing Lights Sensitivity              str
# Loud Sound Sensitivity                   str
# Missed Medication                        str
# Family History of Epilepsy               str
# Head Injury History                      str
# Brain Tumor                              str
# History of Stroke                        str
# Genetic Disorder                         str
# Developmental Delay (in Children)        str
# Epilepsy Type                            str
# dtype: object

# %%
epilepsy.dtypes.value_counts()
# Out:
# str        25
# int64       3
# float64     2
# Name: count, dtype: int64

# %% [markdown]
# ## String Data Type / Categorical Data

# %% [markdown]
# ### Remove leading/trailing whitespace on variables with String data type
#
# Using the column names, we can check its type using .dtypes. If it is a string, we can remove any leading or trailing whitespaces.

# %%
# get column names 
col_names_all = epilepsy.columns.tolist()

for col_name in col_names_all:
    if(epilepsy[col_name].dtypes == 'string'):
        epilepsy[col_name] = epilepsy[col_name].str.strip()

# %% [markdown]
# ### Correcting "Data Entry Mistakes"
#
# We can use value_counts to see the unique values and its corresponding count.

# %%
for colname in col_names_all: 
    if epilepsy[colname].dtypes == 'string': 
        print(epilepsy[colname].value_counts().sort_index())
        print("-"*100)
# Out:
# Gender
# Female    321
# Male      390
# Other      13
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Medication Status
# Not on Medication    186
# On Medication        538
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Alcohol or Drug Use
# No     633
# Yes     91
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# EEG Abnormality Detected
# No      89
# Yes    635
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# MRI/CT Scan Result
# Abnormal    270
# Normal      338
# Not Done    116
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Seizure Type
# Absence          20
# Focal           261
# Generalized     284
# Tonic-Clonic    159
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Aura Before Seizure
# No     258
# Yes    466
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Loss of Consciousness
# No     209
# Yes    515
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Muscle Stiffness
# No     274
# Yes    450
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Jerky Movements
# No     174
# Yes    550
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Postictal Confusion
# No     219
# Yes    505
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Blank Stare Episodes
# No     506
# Yes    218
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Eye Rolling
# No     300
# Yes    424
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Stress or Anxiety Before Episode
# No     241
# Yes    483
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Lack of Sleep Before Episode
# No     218
# Yes    506
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Flashing Lights Sensitivity
# No     356
# Yes    368
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Loud Sound Sensitivity
# No     424
# Yes    300
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Missed Medication
# No     579
# Yes    145
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Family History of Epilepsy
# No     461
# Yes    263
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Head Injury History
# No     566
# Yes    158
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Brain Tumor
# No     702
# Yes     22
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# History of Stroke
# No     661
# Yes     63
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Genetic Disorder
# No     621
# Yes    103
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Developmental Delay (in Children)
# No     696
# Yes     28
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Epilepsy Type
# Focal          290
# Generalized    434
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# By observing the values above, there are no abnormal values for variables with string datatype.

# %% [markdown]
# ### Check for NULL/empty values
#
# Using .isnull() and .sum(), we can see there are no NULL values.

# %%
# columns with NULL/empty values for STRING data type
string_df = epilepsy.select_dtypes('string')
string_df.isnull().sum()
# Out:
# Gender                               0
# Medication Status                    0
# Alcohol or Drug Use                  0
# EEG Abnormality Detected             0
# MRI/CT Scan Result                   0
# Seizure Type                         0
# Aura Before Seizure                  0
# Loss of Consciousness                0
# Muscle Stiffness                     0
# Jerky Movements                      0
# Postictal Confusion                  0
# Blank Stare Episodes                 0
# Eye Rolling                          0
# Stress or Anxiety Before Episode     0
# Lack of Sleep Before Episode         0
# Flashing Lights Sensitivity          0
# Loud Sound Sensitivity               0
# Missed Medication                    0
# Family History of Epilepsy           0
# Head Injury History                  0
# Brain Tumor                          0
# History of Stroke                    0
# Genetic Disorder                     0
# Developmental Delay (in Children)    0
# Epilepsy Type                        0
# dtype: int64

# %% [markdown]
# ## Integer/Float/Quantitative Data

# %% [markdown]
# ### Check for NULL/empty values
#
# Using .isnull() and .sum(), we can see there are no NULL values.

# %%
# columns with NULL/empty values for STRING data type
string_df = epilepsy.select_dtypes(['integer','float'])
string_df.isnull().sum()
# Out:
# Age                  0
# Weight               0
# Height               0
# Seizure Frequency    0
# Seizure Duration     0
# dtype: int64

# %% [markdown]
# ### Impossible values

# %%
quantitative_cols = epilepsy.select_dtypes(['integer','float']).columns.to_list()

# %% [markdown]
# #### Box plot to check for outliers

# %%
fig = plt.figure(figsize=(10, 5), constrained_layout=True)
axs = fig.subplots(1, 5)

for i, col in enumerate(quantitative_cols): 
    ax = axs[i]
    epilepsy[col].plot(kind = 'box', ax = ax)
    ax.set_xlabel(col.lower(), fontsize = 10)
    ax.set_xticklabels('')

# %% [markdown]
# From the boxplots above, we can observe that there are some outliers in variables weight, height, and seizure. These outliers will be investigated using descriptive statistics and scatter plots. The statistics plot can be found below this cell.

# %% [markdown]
# #### Statistics

# %%
fig = plt.figure(figsize=(10, 3), constrained_layout=True)
axs = fig.subplots(1, 5)

for i, col in enumerate(quantitative_cols): 
    ax = axs[i]
    
    summary = epilepsy[col].describe()[['max', 'min','mean', '50%']]
    bars = summary.plot(kind='barh', ax=ax)

    # Add labels at the end of each horizontal bar
    ax.bar_label(bars.containers[0], labels=[f'{v:.2f}' for v in summary.values], padding=3)

    if(col.lower() == 'weight'): 
        col = col.lower() + ' (kg)'
    elif(col.lower() == 'height'): 
        col = col.lower() + ' (cm)'
    elif(col.lower() == 'seizure frequency'): 
        col = col.lower() + ' \n(per month)'
    elif(col.lower() == 'seizure duration'): 
        col = col.lower() + ' \n(average in secs)'
        
    ax.set_xlabel(col.lower(), fontsize = 10)
    ax.set_ylabel('')
    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize =15)

# %% [markdown]
# The statistics tells us that the minimum age is 1 year old. By looking at the Weight vs Age and Height vs Age scatter plots below, age 1 has corresponding weights heavier than 20kg and heights taller than 150cm which is physically impossible. This is indicated using the red lines in the plots.

# %%
fig = plt.figure(figsize=(10, 5), constrained_layout=True)
axs = fig.subplots(1, 2)

sns.scatterplot(data=epilepsy, x="Age", y="Weight", hue="Age", ax=axs[0])
# sns.move_legend(ax,loc="lower center", bbox_to_anchor=(1, 0.5, 0, 1))

axs[0].set_title("Weight Grouped by Age")

axs[0].axvline(x=1, color="red", linestyle="--", linewidth=0.5)

sns.move_legend(axs[0], loc="upper left", bbox_to_anchor=(1, 1))

ax = sns.scatterplot(data=epilepsy, x="Age", y="Height", hue="Age", ax=axs[1])
# sns.move_legend(ax,loc="lower center", bbox_to_anchor=(1, 0.5, 0, 1))

axs[1].set_title("Height Plot Grouped by Age")

axs[1].axvline(x=1, color="red", linestyle="--", linewidth=0.5)

sns.move_legend(axs[1], loc="upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# As epilepsy is triggered by different causes at different age, a set of predefined values are used to check for Biologically Implausible Values(BVI). This values are found using Growth Charts by World Health Orgaisation (WHO) found on The Royoal Children's Hospital Melbourne Website[1]. It is split into age 6 age groups. Ages "0 to 2", "3 to 20 years old.
#
# - [1] https://www.rch.org.au/childgrowth/About_child_growth/Growth_charts/

# %%
def clean_weight_height_data(df):
    # Copy of original dataset to work on
    df_copy = df.copy()

    # Calculate Body Mass Index (BMI)
    # BMI = weight (kg) / (height (m))^2
    height_meters = df_copy["Height"] / 100.0
    df_copy["bmi"] = df_copy["Weight"] / (height_meters**2)

    # 2. Set (Biologically Implausible Values)
    # Age 0 to 2, bmi not included as it isn't appropriate
    age_0_1 = df_copy["Age"] <= 1
    age_0_1 = age_0_1 & (
        (df_copy["Weight"] > 14.5)
        | (df_copy["Weight"] < 2.5)  
        | (df_copy["Height"] > 94)
        | (df_copy["Height"] < 45)  
    )

    # Age 2 to 5, 
    age_2_5 = (df_copy["Age"] >=2) & (df_copy["Age"] <= 5)
    age_2_5= age_2_5 & (
        (df_copy["Weight"] > 25)
        | (df_copy["Weight"] < 10)  
        | (df_copy["Height"] > 117)
        | (df_copy["Height"] < 79)
        | (df_copy["bmi"] > 18.5)
        | (df_copy["bmi"] < 13)
    )

    #  Age 6 to 10, bmi included 
    age_6_10 = (df_copy["Age"] >= 6) & (df_copy["Age"] <= 10) 
    age_6_10 = age_6_10 & (
        (df_copy["Weight"] > 50)
        | (df_copy["Weight"] < 15)
        | (df_copy["Height"] > 150)
        | (df_copy["Height"] < 90)
        | (df_copy["bmi"] > 23.5)
        | (df_copy["bmi"] < 13.5)
    )

    # Age 10 to 15, bmi included 
    age_11_15 = (df_copy["Age"] >= 11) & (df_copy["Age"] <= 15) 
    age_11_15 = age_11_15 & (
        (df_copy["Weight"] > 85)
        | (df_copy["Weight"] < 25)
        | (df_copy["Height"] > 185)
        | (df_copy["Height"] < 125)
        | (df_copy["bmi"] > 29)
        | (df_copy["bmi"] < 14)
    )

    # Age 10 to 15, bmi included 
    age_16_20 = (df_copy["Age"] >= 16) & (df_copy["Age"] <= 20) 
    age_16_20 = age_16_20 & (
        (df_copy["Weight"] > 100)
        | (df_copy["Weight"] < 45)
        | (df_copy["Height"] > 190)
        | (df_copy["Height"] < 155)
        | (df_copy["bmi"] > 32.5)
        | (df_copy["bmi"] < 17)
    )

    
    # adults: Age >20+
    adult_mask = df_copy["Age"] > 20
    adult_mask = adult_mask & (
        (df_copy["Weight"] > 400)
        | (df_copy["Weight"] < 25)
        | (df_copy["Height"] > 200)
        | (df_copy["Height"] < 100)
        | (df_copy["bmi"] > 204)
        | (df_copy["bmi"] < 10)  
    )
    
    # full mask 
    impossible_combinations_mask = age_0_1 | age_2_5 | age_6_10 | age_11_15 | age_16_20 | adult_mask

    # filter data with full mask 
    df_cleaned = df_copy[~impossible_combinations_mask].reset_index(drop=True)

    # Print data audit metrics
    print(f"Original observations: {len(df)}")
    print(f"Removed observations: {impossible_combinations_mask.sum()}")
    print(f"Cleaned observations: {len(df_cleaned)}")
    print(f"Percentage removed: {round((impossible_combinations_mask.sum()/len(df))*100,3)}%")

    return df_cleaned
    # return None

# Run the cleaner
epilepsy_clean = clean_weight_height_data(epilepsy)
epilepsy_clean = epilepsy_clean.drop("bmi", axis = 1)
# Out:
# Original observations: 724
# Removed observations: 103
# Cleaned observations: 621
# Percentage removed: 14.227%

# %%
fig = plt.figure(figsize=(10, 5), constrained_layout=True)
axs = fig.subplots(1, 2)

age_mask = (epilepsy_clean["Age"] >= 2) & (epilepsy_clean["Age"] <=5)
current = epilepsy_clean#[age_mask]

sns.scatterplot(data=current, x="Age", y="Weight", hue="Age", ax=axs[0])
# sns.move_legend(ax,loc="lower center", bbox_to_anchor=(1, 0.5, 0, 1))

axs[0].set_title("Weight Grouped by Age")

axs[0].axvline(x=5, color="red", linestyle="--", linewidth=0.5)

sns.move_legend(axs[0], loc="upper left", bbox_to_anchor=(1, 1))

ax = sns.scatterplot(data=current, x="Age", y="Height", hue="Age", ax=axs[1])
# sns.move_legend(ax,loc="lower center", bbox_to_anchor=(1, 0.5, 0, 1))

axs[1].set_title("Height Plot Grouped by Age")

axs[1].axvline(x=10, color="red", linestyle="--", linewidth=0.5)

sns.move_legend(axs[1], loc="upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# # TEST: Decision Tree

# %%
encoded_epilepsy = pd.get_dummies(
    epilepsy_clean,
    columns=['Gender', 'Medication Status',
       'Alcohol or Drug Use', 'EEG Abnormality Detected', 'MRI/CT Scan Result',
       'Seizure Type',
       'Aura Before Seizure', 'Loss of Consciousness', 'Muscle Stiffness',
       'Jerky Movements', 'Postictal Confusion', 'Blank Stare Episodes',
       'Eye Rolling', 'Stress or Anxiety Before Episode',
       'Lack of Sleep Before Episode', 'Flashing Lights Sensitivity',
       'Loud Sound Sensitivity', 'Missed Medication',
       'Family History of Epilepsy', 'Head Injury History', 'Brain Tumor',
       'History of Stroke', 'Genetic Disorder',
       'Developmental Delay (in Children)'],
    drop_first=False
)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Encode categorical values

# %%
encoded_epilepsy
# Out:
#      Age  Weight  Height  Seizure Frequency  Seizure Duration Epilepsy Type  \
# 0     15    48.3   168.2                  1                60   Generalized
# 1     36    44.8   156.2                  3                30   Generalized
# 2     32    70.4   180.4                  0                60         Focal
# 3     29    54.5   161.7                  1                60   Generalized
# 4     18    62.1   168.0                  1                30   Generalized
# ..   ...     ...     ...                ...               ...           ...
# 616   18    62.8   168.5                  1                60   Generalized
# 617   36    69.2   168.3                  3                30   Generalized
# 618   54    73.9   168.0                  2                90         Focal
# 619   44    55.1   171.7                  0                60         Focal
# 620   65    50.9   169.4                 10               120         Focal
#
#      Gender_Female  Gender_Male  Gender_Other  \
# 0            False         True         False
# 1             True        False         False
# 2             True        False         False
# 3            False         True         False
# 4            False         True         False
# ..             ...          ...           ...
# 616          False         True         False
# 617           True        False         False
# 618           True        False         False
# 619           True        False         False
# 620           True        False         False
#
#      Medication Status_Not on Medication  Medication Status_On Medication  \
# 0                                  False                             True
# 1                                  False                             True
# 2                                   True                            False
# 3                                  False                             True
# 4                                  False                             True
# ..                                   ...                              ...
# 616                                False                             True
# 617                                False                             True
# 618                                False                             True
# 619                                 True                            False
# 620                                False                             True
#
#      Alcohol or Drug Use_No  Alcohol or Drug Use_Yes  \
# 0                     False                     True
# 1                      True                    False
# 2                      True                    False
# 3                      True                    False
# 4                      True                    False
# ..                      ...                      ...
# 616                    True                    False
# 617                    True                    False
# 618                    True                    False
# 619                    True                    False
# 620                    True                    False
#
#      EEG Abnormality Detected_No  EEG Abnormality Detected_Yes  \
# 0                          False                          True
# 1                          False                          True
# 2                          False                          True
# 3                          False                          True
# 4                          False                          True
# ..                           ...                           ...
# 616                        False                          True
# 617                        False                          True
# 618                        False                          True
# 619                        False                          True
# 620                        False                          True
#
#      MRI/CT Scan Result_Abnormal  MRI/CT Scan Result_Normal  \
# 0                          False                       True
# 1                           True                      False
# 2                          False                      False
# 3                          False                      False
# 4                           True                      False
# ..                           ...                        ...
# 616                         True                      False
# 617                         True                      False
# 618                        False                       True
# 619                        False                      False
# 620                         True                      False
#
#      MRI/CT Scan Result_Not Done  Seizure Type_Absence  Seizure Type_Focal  \
# 0                          False                 False               False
# 1                          False                 False               False
# 2                           True                 False                True
# 3                           True                 False               False
# 4                          False                 False               False
# ..                           ...                   ...                 ...
# 616                        False                 False               False
# 617                        False                 False               False
# 618                        False                 False                True
# 619                         True                 False                True
# 620                        False                 False                True
#
#      Seizure Type_Generalized  Seizure Type_Tonic-Clonic  \
# 0                       False                       True
# 1                       False                       True
# 2                       False                      False
# 3                       False                       True
# 4                       False                       True
# ..                        ...                        ...
# 616                     False                       True
# 617                      True                      False
# 618                     False                      False
# 619                     False                      False
# 620                     False                      False
#
#      Aura Before Seizure_No  Aura Before Seizure_Yes  \
# 0                      True                    False
# 1                     False                     True
# 2                     False                     True
# 3                      True                    False
# 4                     False                     True
# ..                      ...                      ...
# 616                    True                    False
# 617                   False                     True
# 618                   False                     True
# 619                    True                    False
# 620                   False                     True
#
#      Loss of Consciousness_No  Loss of Consciousness_Yes  Muscle Stiffness_No  \
# 0                       False                       True                 True
# 1                        True                      False                False
# 2                       False                       True                 True
# 3                       False                       True                False
# 4                       False                       True                 True
# ..                        ...                        ...                  ...
# 616                     False                       True                False
# 617                      True                      False                 True
# 618                     False                       True                 True
# 619                     False                       True                False
# 620                     False                       True                False
#
#      Muscle Stiffness_Yes  Jerky Movements_No  Jerky Movements_Yes  \
# 0                   False               False                 True
# 1                    True               False                 True
# 2                   False               False                 True
# 3                    True               False                 True
# 4                   False               False                 True
# ..                    ...                 ...                  ...
# 616                  True               False                 True
# 617                 False                True                False
# 618                 False               False                 True
# 619                  True                True                False
# 620                  True               False                 True
#
#      Postictal Confusion_No  Postictal Confusion_Yes  Blank Stare Episodes_No  \
# 0                     False                     True                     True
# 1                      True                    False                    False
# 2                     False                     True                    False
# 3                     False                     True                     True
# 4                     False                     True                    False
# ..                      ...                      ...                      ...
# 616                   False                     True                     True
# 617                   False                     True                    False
# 618                   False                     True                     True
# 619                   False                     True                     True
# 620                    True                    False                    False
#
#      Blank Stare Episodes_Yes  Eye Rolling_No  Eye Rolling_Yes  \
# 0                       False           False             True
# 1                        True           False             True
# 2                        True            True            False
# 3                       False            True            False
# 4                        True            True            False
# ..                        ...             ...              ...
# 616                     False           False             True
# 617                      True            True            False
# 618                     False            True            False
# 619                     False           False             True
# 620                      True            True            False
#
#      Stress or Anxiety Before Episode_No  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 616                                False
# 617                                False
# 618                                False
# 619                                False
# 620                                False
#
#      Stress or Anxiety Before Episode_Yes  Lack of Sleep Before Episode_No  \
# 0                                    True                            False
# 1                                    True                             True
# 2                                    True                            False
# 3                                    True                             True
# 4                                    True                            False
# ..                                    ...                              ...
# 616                                  True                            False
# 617                                  True                            False
# 618                                  True                             True
# 619                                  True                             True
# 620                                  True                            False
#
#      Lack of Sleep Before Episode_Yes  Flashing Lights Sensitivity_No  \
# 0                                True                           False
# 1                               False                            True
# 2                                True                           False
# 3                               False                            True
# 4                                True                           False
# ..                                ...                             ...
# 616                              True                           False
# 617                              True                           False
# 618                             False                           False
# 619                             False                           False
# 620                              True                            True
#
#      Flashing Lights Sensitivity_Yes  Loud Sound Sensitivity_No  \
# 0                               True                      False
# 1                              False                      False
# 2                               True                      False
# 3                              False                      False
# 4                               True                       True
# ..                               ...                        ...
# 616                             True                       True
# 617                             True                       True
# 618                             True                       True
# 619                             True                       True
# 620                            False                      False
#
#      Loud Sound Sensitivity_Yes  Missed Medication_No  Missed Medication_Yes  \
# 0                          True                  True                  False
# 1                          True                 False                   True
# 2                          True                  True                  False
# 3                          True                  True                  False
# 4                         False                  True                  False
# ..                          ...                   ...                    ...
# 616                       False                 False                   True
# 617                       False                  True                  False
# 618                       False                  True                  False
# 619                       False                  True                  False
# 620                        True                 False                   True
#
#      Family History of Epilepsy_No  Family History of Epilepsy_Yes  \
# 0                             True                           False
# 1                            False                            True
# 2                             True                           False
# 3                            False                            True
# 4                            False                            True
# ..                             ...                             ...
# 616                           True                           False
# 617                           True                           False
# 618                           True                           False
# 619                           True                           False
# 620                           True                           False
#
#      Head Injury History_No  Head Injury History_Yes  Brain Tumor_No  \
# 0                      True                    False            True
# 1                      True                    False            True
# 2                      True                    False            True
# 3                      True                    False           False
# 4                      True                    False            True
# ..                      ...                      ...             ...
# 616                    True                    False            True
# 617                    True                    False            True
# 618                   False                     True            True
# 619                   False                     True            True
# 620                   False                     True            True
#
#      Brain Tumor_Yes  History of Stroke_No  History of Stroke_Yes  \
# 0              False                  True                  False
# 1              False                  True                  False
# 2              False                  True                  False
# 3               True                  True                  False
# 4              False                  True                  False
# ..               ...                   ...                    ...
# 616            False                  True                  False
# 617            False                  True                  False
# 618            False                  True                  False
# 619            False                  True                  False
# 620            False                  True                  False
#
#      Genetic Disorder_No  Genetic Disorder_Yes  \
# 0                   True                 False
# 1                   True                 False
# 2                   True                 False
# 3                   True                 False
# 4                   True                 False
# ..                   ...                   ...
# 616                 True                 False
# 617                 True                 False
# 618                 True                 False
# 619                 True                 False
# 620                 True                 False
#
#      Developmental Delay (in Children)_No  \
# 0                                   False
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
# ..                                    ...
# 616                                  True
# 617                                  True
# 618                                  True
# 619                                  True
# 620                                  True
#
#      Developmental Delay (in Children)_Yes
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 616                                  False
# 617                                  False
# 618                                  False
# 619                                  False
# 620                                  False
#
# [621 rows x 58 columns]

# %%
# validation strategy 
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score

# models
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier

# error measure/metrics
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report

# %%
# get features data, 
X = encoded_epilepsy.drop('Epilepsy Type', axis=1)
# get labels, i.e. last column 
y = encoded_epilepsy['Epilepsy Type']

# %%
# check shape of data 
print(f'data: {X.shape}, label: {y.shape}')
# Out:
# data: (621, 57), label: (621,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0, stratify = y)

# %%
# check shape of train and test data set 
print(f'X_train\t: {X_train.shape}, y_train\t: {y_train.shape}\nX_test\t: {X_test.shape}, y_test\t: {y_test.shape}')
# Out:
# X_train	: (496, 57), y_train	: (496,)
# X_test	: (125, 57), y_test	: (125,)

# %%
# set of values for each parameter
max_depth_vals = [5, 7, 10, 12, 15, 17]
min_samples_split_vals = [2, 5, 10, 20, 50, 100]
min_samples_leaf_vals = [1, 2, 3, 5, 10, 20]

max_depth_his = list()
min_samples_his = list()
min_leafs_his = list()
corr_avg = list() 

for max_depth in max_depth_vals:
    for min_sample in min_samples_split_vals: 
        for min_leaf in min_samples_leaf_vals: 
            acc_scores = list() 

            # instance of Decision Tree for each parameter set
            dt_clf = DecisionTreeClassifier(max_depth = max_depth, min_samples_split = min_sample, min_samples_leaf = min_leaf)
            
            # get average scores of each k fold 
            acc_scores = cross_val_score(dt_clf, X_train, y_train, cv = 10, scoring = 'accuracy')
            
            # find average score across all folds 
            avg_score = acc_scores.mean()
    
            print(f'With max_depth={max_depth}, min_samples_split={min_sample}, and min_samples_leaf={min_leaf}, the average accurary is {avg_score}')
            
            max_depth_his.append(max_depth)
            min_samples_his.append(min_sample)
            min_leafs_his.append(min_leaf)
            corr_avg.append(avg_score)
# Out:
# With max_depth=5, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8889795918367346
# With max_depth=5, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8788979591836735
# With max_depth=5, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8869387755102041
# With max_depth=5, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8829795918367346
# With max_depth=5, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=5, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9071428571428571
# With max_depth=5, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8889387755102041
# With max_depth=5, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8870204081632653
# With max_depth=5, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8869387755102041
# With max_depth=5, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=5, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8891020408163264
# With max_depth=5, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=5, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8849387755102042
# With max_depth=5, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.882938775510204
# With max_depth=5, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8889387755102041
# With max_depth=5, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=5, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8971020408163264
# With max_depth=5, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=5, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=5, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=5, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=5, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9091836734693877
# With max_depth=5, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=5, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8788571428571428
# With max_depth=7, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8890612244897959
# With max_depth=7, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8828979591836734
# With max_depth=7, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8789387755102039
# With max_depth=7, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=7, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9091836734693878
# With max_depth=7, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8788571428571428
# With max_depth=7, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8749387755102042
# With max_depth=7, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8829795918367346
# With max_depth=7, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=7, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=7, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=7, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8909795918367347
# With max_depth=7, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8869795918367348
# With max_depth=7, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8910204081632654
# With max_depth=7, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=7, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=7, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=7, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=7, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.872938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=7, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=7, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9091428571428573
# With max_depth=7, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=7, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8888571428571428
# With max_depth=10, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8728163265306123
# With max_depth=10, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8828979591836734
# With max_depth=10, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=10, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=10, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=10, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8848979591836736
# With max_depth=10, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8871020408163266
# With max_depth=10, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8830204081632653
# With max_depth=10, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8829795918367347
# With max_depth=10, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=10, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9091836734693877
# With max_depth=10, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8929795918367347
# With max_depth=10, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8849795918367347
# With max_depth=10, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8890204081632653
# With max_depth=10, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8829795918367346
# With max_depth=10, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=10, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9132653061224489
# With max_depth=10, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.874938775510204
# With max_depth=10, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.8769387755102039
# With max_depth=10, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8769387755102039
# With max_depth=10, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=10, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=10, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=10, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=10, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8808979591836735
# With max_depth=12, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8808979591836733
# With max_depth=12, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.8868979591836734
# With max_depth=12, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8849795918367347
# With max_depth=12, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=12, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=12, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.880857142857143
# With max_depth=12, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8850612244897957
# With max_depth=12, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.882938775510204
# With max_depth=12, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=12, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=12, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9111836734693878
# With max_depth=12, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869795918367348
# With max_depth=12, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8849795918367347
# With max_depth=12, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8890204081632653
# With max_depth=12, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=12, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=12, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9071428571428571
# With max_depth=12, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.872938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.874938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8769387755102039
# With max_depth=12, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=12, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=12, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=12, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=12, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8829387755102042
# With max_depth=15, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.8910204081632653
# With max_depth=15, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.884938775510204
# With max_depth=15, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.8809795918367346
# With max_depth=15, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=15, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=15, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8808571428571428
# With max_depth=15, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8829795918367347
# With max_depth=15, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.884938775510204
# With max_depth=15, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=15, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=15, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9132244897959184
# With max_depth=15, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8909795918367347
# With max_depth=15, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8829795918367347
# With max_depth=15, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8910204081632654
# With max_depth=15, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=15, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=15, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9132653061224489
# With max_depth=15, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.874938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.872938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8769387755102039
# With max_depth=15, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=15, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8891020408163264
# With max_depth=15, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=15, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=15, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=2, and min_samples_leaf=1, the average accurary is 0.8909795918367347
# With max_depth=17, min_samples_split=2, and min_samples_leaf=2, the average accurary is 0.878938775510204
# With max_depth=17, min_samples_split=2, and min_samples_leaf=3, the average accurary is 0.880938775510204
# With max_depth=17, min_samples_split=2, and min_samples_leaf=5, the average accurary is 0.880938775510204
# With max_depth=17, min_samples_split=2, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=17, min_samples_split=2, and min_samples_leaf=20, the average accurary is 0.9071428571428571
# With max_depth=17, min_samples_split=5, and min_samples_leaf=1, the average accurary is 0.8828979591836734
# With max_depth=17, min_samples_split=5, and min_samples_leaf=2, the average accurary is 0.8748571428571429
# With max_depth=17, min_samples_split=5, and min_samples_leaf=3, the average accurary is 0.8909795918367346
# With max_depth=17, min_samples_split=5, and min_samples_leaf=5, the average accurary is 0.8829795918367346
# With max_depth=17, min_samples_split=5, and min_samples_leaf=10, the average accurary is 0.8931020408163265
# With max_depth=17, min_samples_split=5, and min_samples_leaf=20, the average accurary is 0.9091836734693878
# With max_depth=17, min_samples_split=10, and min_samples_leaf=1, the average accurary is 0.8869795918367348
# With max_depth=17, min_samples_split=10, and min_samples_leaf=2, the average accurary is 0.8829795918367346
# With max_depth=17, min_samples_split=10, and min_samples_leaf=3, the average accurary is 0.8970204081632653
# With max_depth=17, min_samples_split=10, and min_samples_leaf=5, the average accurary is 0.8769387755102039
# With max_depth=17, min_samples_split=10, and min_samples_leaf=10, the average accurary is 0.8951020408163265
# With max_depth=17, min_samples_split=10, and min_samples_leaf=20, the average accurary is 0.9112244897959183
# With max_depth=17, min_samples_split=20, and min_samples_leaf=1, the average accurary is 0.8769387755102039
# With max_depth=17, min_samples_split=20, and min_samples_leaf=2, the average accurary is 0.872938775510204
# With max_depth=17, min_samples_split=20, and min_samples_leaf=3, the average accurary is 0.8769387755102039
# With max_depth=17, min_samples_split=20, and min_samples_leaf=5, the average accurary is 0.870938775510204
# With max_depth=17, min_samples_split=20, and min_samples_leaf=10, the average accurary is 0.8911020408163266
# With max_depth=17, min_samples_split=20, and min_samples_leaf=20, the average accurary is 0.9111836734693879
# With max_depth=17, min_samples_split=50, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=50, and min_samples_leaf=20, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=1, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=2, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=3, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=5, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=10, the average accurary is 0.8910612244897959
# With max_depth=17, min_samples_split=100, and min_samples_leaf=20, the average accurary is 0.8910612244897959

# %%
max_ind = np.argmax(corr_avg)
best_max_depth = max_depth_his[max_ind]
best_min_samples_split = min_samples_his[max_ind]
best_min_leafs = min_leafs_his[max_ind]

print(f'The best acc is {corr_avg[max_ind]} with parameters:\n- max_depth\t\t=\t{best_max_depth}\n- min_samples_split\t=\t{best_min_samples_split}\n- min_samples_leaf\t=\t{best_min_leafs}')
# Out:
# The best acc is 0.9132653061224489 with parameters:
# - max_depth		=	10
# - min_samples_split	=	10
# - min_samples_leaf	=	20

# %%
# create instace of KNN with the best max_depth, min_samples_split, and min_samples_leaf values
dt_clf = DecisionTreeClassifier(max_depth = best_max_depth, min_samples_split = best_min_samples_split, min_samples_leaf = best_min_leafs)

# fit data into model 
dt_fit = dt_clf.fit(X_train, y_train)

# predict with test data set 
dt_predicted = dt_fit.predict(X_test)

# confusion matrix
confusion_matrix(y_test, dt_predicted)
# Out:
# array([[46,  6],
#        [ 8, 65]])

# %%
print(classification_report(y_test, dt_predicted))
# Out:
#               precision    recall  f1-score   support
#
#        Focal       0.85      0.88      0.87        52
#  Generalized       0.92      0.89      0.90        73
#
#     accuracy                           0.89       125
#    macro avg       0.88      0.89      0.89       125
# weighted avg       0.89      0.89      0.89       125
