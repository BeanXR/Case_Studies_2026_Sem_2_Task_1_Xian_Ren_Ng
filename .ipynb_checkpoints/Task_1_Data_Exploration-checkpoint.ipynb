# %% [markdown]
# # Load required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset

# %%
# load epilepsy dataset 
epilepsy = pd.read_csv("./Datasets/EpilepsyCleaned.csv", sep= ',', decimal= '.', on_bad_lines = 'error', skip_blank_lines=False)

# load dementia dataset 
dementia = pd.read_csv("./Datasets/DementiaCleaned.csv", sep= ',', decimal= '.', on_bad_lines = 'error', skip_blank_lines=False)

# %% [markdown]
# # Check Data Load is correct

# %%
pd.set_option('display.max_columns', None)

# %%
epilepsy.head()
# Out:
#    Age  Gender  Weight  Height  Medication Status Alcohol or Drug Use  \
# 0   15    Male    48.3   168.2      On Medication                 Yes
# 1   36  Female    44.8   156.2      On Medication                  No
# 2   32  Female    70.4   180.4  Not on Medication                  No
# 3   29    Male    54.5   161.7      On Medication                  No
# 4   18    Male    62.1   168.0      On Medication                  No
#
#   EEG Abnormality Detected MRI/CT Scan Result  Seizure Frequency  \
# 0                      Yes             Normal                  1
# 1                      Yes           Abnormal                  3
# 2                      Yes           Not Done                  0
# 3                      Yes           Not Done                  1
# 4                      Yes           Abnormal                  1
#
#    Seizure Duration  Seizure Type Aura Before Seizure Loss of Consciousness  \
# ...

# %%
pd.reset_option('display.max_columns')

# %%
dementia.head()
# Out:
#          Group  Visit M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  Nondemented      1   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1  Nondemented      2   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2  Nondemented      1   F   88    18  3.0  28.0  0.0  1215  0.710  1.444
# 3  Nondemented      2   F   90    18  3.0  27.0  0.0  1200  0.718  1.462
# 4  Nondemented      1   M   80    12  4.0  28.0  0.0  1689  0.712  1.039

# %% [markdown]
# # Epilepsy Dataset

# %% [markdown]
# ## Quantitative Variables

# %% [markdown]
# ### Weight, Height, and Age per Epilepsy type

# %%
fig = plt.figure(figsize=(8,5), constrained_layout=True)
axs = fig.subplots(1, 3) 

target_vars = ["Weight", "Height", "Age"]

for i, var in enumerate(target_vars):
    # sns.boxplot(data=epilepsy, x="Epilepsy Type", y=var, ax=axs[i])
    epilepsy.boxplot(column=var, by='Epilepsy Type',ax=axs[i])
    axs[i].set_title(var)
    

fig.suptitle('Weight, Height, Age Distribution per epilepsy type')
# Out:
# Text(0.5, 0.98, 'Weight, Height, Age Distribution per epilepsy type')

# %% [markdown]
# The boxplots with main title "Weight, Height, Age Distribution per epilepsy type" above shows the distribution of variables Age, Weight and Height per epilepsy type. We can observe that the distribution is similar between Generalised and Focal. There are a few outliers in both Weight and Height. However, this was discussed and concluded that they are valid values in the (data cleaning section for impossible values). This shows that these three variables are not useful indicators to distinguish between between epilepsy type.

# %% [markdown]
# ### Seizure Frequency and Duration

# %%
epilepsy.groupby('Epilepsy Type')['Seizure Frequency'].describe()
# Out:
#                count      mean       std  min  25%  50%  75%   max
# Epilepsy Type
# Focal          257.0  2.073930  2.575118  0.0  0.0  1.0  2.0  10.0
# Generalised    364.0  1.978022  2.379796  0.0  0.0  1.0  3.0  10.0

# %%
fig = plt.figure(figsize=(8,5), constrained_layout=True)
axs = fig.subplots(2, 2).flatten()

target_vars = ['Seizure Frequency', 'Seizure Duration']
titles = ['Seizure Frequency\n (per month)', 'Seizure Duration\n (in secs)']

for i, var in enumerate(target_vars):
    # sns.boxplot(data=epilepsy, x="Epilepsy Type", y=var, ax=axs[i])
    epilepsy.boxplot(column=var, by='Epilepsy Type',ax=axs[i])
    
    axs[i].set_title(titles[i])
    axs[i].title.set_fontsize(10)

for i, var in enumerate(target_vars):
    summary = epilepsy.groupby('Epilepsy Type')[var].describe()[['mean', 'std']]
    summary.plot(kind='barh', ax=axs[i+2])
    
    axs[i+2].set_title(titles[i])
    axs[i+2].title.set_fontsize(10)
    
fig.suptitle('Seizure Frequency and Seizure Duration per epilepsy type')
# Out:
# Text(0.5, 0.98, 'Seizure Frequency and Seizure Duration per epilepsy type')

# %% [markdown]
# The boxplots above shows the distribution of seizure frequency and duration are similar between epilepsy type. Seizure frequency both has outliers at 10 seizures per month and the same max and min values. However, Focal has a smaller interquartile range which suggests Generalised has more patients with slightly higher seizure frequency. Seizure duration are almost identical between Generalised and Focal. The mean and standard deviation are plotted on the bottom row and the values are similar as well. This suggest Sizure Frequency and Duration alone may not be good indicators to differentiate between epilepsy types.

# %% [markdown]
# ## Qualitative Data

# %% [markdown]
# ### Explore binary columns (Yes/No) to distinguish between Epilepsy Type

# %% [markdown]
# The features that are explored below are categorical variables with values 'Yes' and 'No'. As different epilepsy type have different symptoms, these variable may help machine learning models to distinguish between types. To find features that may distinguish epilepsy type, bar charts are used to show percentages of 'Yes'es within each epilepsy type. First we will group the variables in epilepsy type, count the number of 'Yes'es and find its percentage.
#
# Function below plots 5 subplots with one variable in each.

# %%
def plot_five(five_vars):
    fig = plt.figure(figsize=(10,3), constrained_layout=True)
    axs = fig.subplots(1, len(five_vars)) 
    
    for i, feature in enumerate(features): 
        # calculate the percentages of "Yes" for each Epilepsy Type - rmb: after grouping, apply works on group 
        # (x == 'Yes') returns a series of True and False / 0 or 1, using mean() get the percentage of yeses within each var 
        yes_percentages = epilepsy.groupby('Epilepsy Type')[feature].apply(lambda x: (x == 'Yes').mean() * 100).reset_index(name='percentage')
        
        ax = axs[i]
        sns.barplot(data=yes_percentages, x='Epilepsy Type', y='percentage', ax=ax)

        # some edge cases to prevent title from overlapping
        if(feature == 'Stress or Anxiety Before Episode'):
            feature = 'Stress or Anxiety \nBefore Episode'
        elif(feature == 'Lack of Sleep Before Episode'): 
            feature = 'Lack of Sleep \nBefore Episode'
        elif(feature == 'Developmental Delay (in Children)'):
            feature = 'Developmental Delay \n(in Children)'
        elif(feature == 'EEG Abnormality Detected'):
            feature = 'EEG Abnormality \nDetected'
        
        ax.set_title(feature.lower())
        ax.tick_params(axis = 'x', labelsize = 10)
        ax.set_xlabel('Epilepsy Type', fontsize=7)
        
    fig.suptitle('Yes percentages within each Epilepsy Type', fontsize=13)

# %%
features = ['Aura Before Seizure', 'Loss of Consciousness', 'Muscle Stiffness', 'Jerky Movements', 'Postictal Confusion']
plot_five(features)

# %%
features = ['Blank Stare Episodes', 'Eye Rolling', 'Stress or Anxiety Before Episode', 'Lack of Sleep Before Episode', 'Flashing Lights Sensitivity']
plot_five(features)

# %%
features = ['Loud Sound Sensitivity', 'Missed Medication', 'Family History of Epilepsy', 'Head Injury History', 'Brain Tumor']
plot_five(features)

# %%
features = ['History of Stroke', 'Genetic Disorder', 'Developmental Delay (in Children)', 'Alcohol or Drug Use', 'EEG Abnormality Detected']
plot_five(features)

# %% [markdown]
# #### Variables with larger differences in Yes percentages

# %% [markdown]
# From the plots above, variables with larger differences in percentages are 'Loss of Consciousness', 'Jerky Movements', 'Developmental Delay (in Children)', 'Aura Before Seizure'. Their plots can be found below.

# %%
features = ['Loss of Consciousness', 'Jerky Movements', 'Developmental Delay (in Children)', 'Aura Before Seizure']
plot_five(features)

# %% [markdown]
# These variables will be discussed here:
# 1. Loss of Conciousness, this variable indicates whether if conciousness is lost during a seizure. Focal has 40% and Generalised has around 90%.
# 2. Jerkey Movements, this variable indicates any rhythmic body movements during seizure. Focal has around 50% and Generalised has around 90%.
#
# We can clearly see that patients that are categorised as Generalised has a much higher percentage in having these symptomps.
#
# 3. Developmental Delay, the percentages for this variable very low. Hence, it will not be explored for this section.
# 4. Aura before Seizure, this variable indicates whether presence of sensory warning signs before a seizure. This includes sparkling lights or blurry vision. Focal has around 90% and Generalised has around 50%. This is a good indicator as Focal type is known for having aura [1].
#
# Even though most of the variables have similar percentages, the machine learning model such as decision tree will take the different combinations of these variables into account.
#
# - [1] https://www.epilepsy.com/what-is-epilepsy/seizure-types

# %% [markdown]
# ## Explore a few multivariate comparisons
# This section involves bivariate comparisons. The 4 possible combinations of yes and no will be plotted - (no,no), (no,yes), (yes,no) and (yes,yes).
#
# Let's define a function to produce bivariate plots grouped by epilepsy type

# %%
def bivariate_plot(f1, f2): 
    ct = pd.crosstab([epilepsy[f1], epilepsy[f2]], epilepsy['Epilepsy Type'])
    ct.plot(kind='bar', color=['red','blue'], grid=True)
    plt.xticks(rotation=0)
    plt.title(f'{f1} & {f2}')

# %%
bivariate_plot('Loss of Consciousness', 'Jerky Movements')

# %% [markdown]
# From the plot above named 'Loss of Consciousness & Jerky Movements', we can observe Generalised has a much higher count for patients having both "Loss of Conciousness" and "Jerky Movements". Focal is spread out more in the other combinations. This suggests this feature pair may be informative for a classification model.

# %%
bivariate_plot('Aura Before Seizure', 'Flashing Lights Sensitivity')

# %% [markdown]
# From the boxplot above named 'Aura Before Seizure & Flashing Lights Sensitivity', we can observe that count for focal is higher for combinations of (Yes,No) and (Yes,Yes) - right two graphs - while count for Generalised is much higher for combinations (No,No) and (No,Yes) - left two graphs. This suggests this feature pair may be informative for a classification model.

# %% [markdown]
# Now we have some idea that combinations of different features may be informative for differentiating between classes. Higher number of combinations may even work better which may work well with a decision tree model.

# %% [markdown]
# # Dementia Dataset

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Prepare data for plotting convenience. The dictionary will consist of three keys, each key is one of the value from Group - nondemented, demented, and converted. Its corresponding value is a dataframe where each observation falls within that Group category.

# %%
dementia_dict = dict()
dementia_groups = dementia['Group'].value_counts().index.tolist()

for i in dementia_groups: 
    dementia_dict[i] = dementia[dementia['Group'] == i]

# %% [markdown]
# ## Quantitative Variables
#
# Let's define a function to produce histogram and summary statistics for a single variable grouped by Dementia - Group variable

# %%
def plot_hist_stats(feature):
    fig = plt.figure(figsize=(20, 6), constrained_layout=True)
    subfigs = fig.subfigures(2, 1)
    feature = feature
    title = [f'{feature} - histogram and density plot', f'{feature} - Statistics']
    
    for j, subfig in enumerate(subfigs):
        subfig.suptitle(title[j], fontsize = 20)
        axs = subfig.subplots(1, len(dementia_groups)) 
        
        for i, group in enumerate(dementia_groups): 
            ax = axs[i]
    
            if(j == 0): 
                sns.histplot(dementia_dict[group][feature], kde=True, stat="density", color="skyblue", ax=ax)
                ax.set_ylabel('Density', fontsize = 17)
            elif(j == 1): 
                summary = dementia_dict[group][feature].describe()[['min', 'max', 'mean', '50%']]
                summary.plot(kind='barh', ax=ax)
                ax.set_ylabel('', fontsize = 17)
                
                # Add value labels on the bars
                for container in ax.containers:
                    ax.bar_label(container, fmt='%.1f', fontsize=15, padding=5)
                    
            ax.set_xlabel(group.lower(), fontsize = 17)
            ax.tick_params(axis = 'x', labelsize = 17)
            ax.tick_params(axis = 'y', labelsize = 17)

# %% [markdown]
# # Explore a few Quantitative variables

# %%
plot_hist_stats('Age')

# %% [markdown]
# The plot above shows the distribution of age for each dementia group. The distribution for none-demented is almost normal, demented is slightly right-skewed, and converted is slightly left skewed. The converted skewness makes sense as converted are patients who were diagnosed with dementia on later visits. Left-skewed shows that bulk of the data is in higher end of the data. This shows patients developed dementia in older age which is common.

# %%
plot_hist_stats('EDUC')

# %% [markdown]
# The plot aboves shows the distribution of years of education. The distribution dentisy of nonmented is much higher than demented and converted. This suggest people with more education reduces their risk of getting dementia. This can be useful for dementia research.

# %%
plot_hist_stats('MMSE')

# %% [markdown]
# The plot above shows the distribution of MMSE which stands for minimental state examination. It is a scoring point system which ranges from 0 to 30. Patients are asked 20 questions that assesses their cognitive domains and functions [1]. The higher the score, the better their cognitive functions. All three distributions are left skewed. However, we can observe that the distribution density is much higher for nondemented. This suggests people with higher cognitive functions tend to have a lower risk of developing dementia.
#
# - [1] https://www.sciencedirect.com/science/chapter/monograph/pii/B9780323778466000069

# %%
plot_hist_stats('CDR')

# %% [markdown]
# The plot above shows the distribution and statistics for Clinical Dementia Ratio (CDR). The value and its corresponding meaning are 0 = no dementia, 0.5 = questionable, 1 = mild, 2 = moderate, 3 = severe. As expected, in non-demented value 0 has the highest density. Converted ranged from 0 up to 0.5. Demented starts with 0.5 and ranges to 2. This will be a strong indicator for the machine learning model to distinguish between types.

# %%
plot_hist_stats('eTIV')

# %% [markdown]
# The plot above shows the distribution and statistics for eTIV which stands for Estimated Total Intracranial Volume. It measures the approximate size inside of a person's skull. It is measure in cm^3. The distribution and statistics are about the same for each dementia Group. This variable itself might not be a good indicator to differentiate between Groups.

# %%
plot_hist_stats('nWBV')

# %% [markdown]
# The plot above shows the distribution and statistics for nwbv which stands for Normalized whole-brain volume. Just like eTIV, the distribution and statistics are similar for each dementia Group. Again, this variable itself might not be a good indicator to differentiate between Groups.

# %% [markdown]
# for future use:

# %%
def plot_scatter(x,y):
    fig, axes = plt.subplots(1, 3, figsize=(35, 7), constrained_layout=True)
    axes = axes.flatten()
    y = y
    x = x
    fig.suptitle(f'{y} vs {x}', fontsize = 30)
    
    for i, group in enumerate(dementia_groups): 
        ax = axes[i]
        ax.scatter(dementia_dict[group][x], dementia_dict[group][y], s= 10)
        ax.set_xlabel(f'{x}\n{group.lower()}', fontsize = 25)
        ax.set_ylabel(y, fontsize = 25)
        ax.tick_params(axis = 'x', labelsize = 25, rotation = 45)
        ax.tick_params(axis = 'y', labelsize = 25)
